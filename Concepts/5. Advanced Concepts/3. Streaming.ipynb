# %% [markdown]
# # Advanced Operations for LLM Input / Output with LangChain
#
# This notebook covers the following operations:
#
# - Streaming

# %%
# !pip install -qq langchain==0.3.11
# !pip install -qq langchain-openai==0.2.12
# !pip install -qq langchain-community==0.3.11

# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_openai import ChatOpenAI

chatgpt = ChatOpenAI(model_name="gpt-4o-mini", temperature=0)

# %% [markdown]
# ## Streaming in LLMs
#
# All language model interfaces (LLMs) in LangChain implement the `Runnable` interface, which provides default methods such as `ainvoke`, `batch`, `abatch`, `stream`, and `astream`. This setup equips all LLMs with basic streaming capabilities.
#
# ### Streaming Defaults:
#
# - **Synchronous Streaming:** By default, streaming operations return an `Iterator` that yields a single value, the final result from the LLM provider.
# - **Asynchronous Streaming:** Similarly, async streaming defaults to returning an `AsyncIterator` with the final result.
#
# ### Limitations:
#
# - These default implementations do not support token-by-token streaming. For such detailed streaming, the LLM provider must offer native support. However, the default setup ensures that your code expecting an iterator of tokens will function correctly within these constraints.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate

chatgpt = ChatOpenAI(model_name="gpt-4o-mini", temperature=0)

prompt = """Explain to me what is mortgage in detail with pros and cons"""
chat_template = ChatPromptTemplate.from_template(prompt)

for chunk in chatgpt.stream(chat_template.format()):
    print(chunk.content)
# Out:
# A
#  mortgage
#  is
#  a
#  type
#  of
#  loan
#  specifically
#  used
#  to
#  purchase
#  real
#  estate
# ,
#  where
#  the
#  property
#  itself
#  serves
#  as
#  collateral
#  for
#  the
#  loan
# .
#  When
#  a
#  borrower
#  takes
#  out
#  a
#  mortgage
# ,
#  they
#  agree
#  to
#  repay
#  the
#  loan
#  amount
# ,
#  plus
#  interest
# ,
#  over
#  a
#  specified
#  period
# ,
#  typically
#
# 15
#  to
#
# 30
#  years
# .
#  Mort
# gages
#  are
#  commonly
#  used
#  by
#  individuals
#  and
#  families
#  to
#  buy
#  homes
# ,
#  but
#  they
#  can
#  also
#  be
#  used
#  for
#  investment
#  properties
#  or
#  commercial
#  real
#  estate
# .
#
#
# ###
#  Key
#  Components
#  of
#  a
#  Mortgage
#
#
#
# 1
# .
#  **
# Principal
# **
# :
#  The
#  original
#  loan
#  amount
#  borrowed
#  from
#  the
#  lender
# .
#
# 2
# .
#  **
# Interest
#  Rate
# **
# :
#  The
#  cost
#  of
#  borrowing
#  the
#  principal
# ,
#  expressed
#  as
#  a
#  percentage
# .
#  This
#  can
#  be
#  fixed
#  (
# rem
# ains
#  the
#  same
#  throughout
#  the
#  loan
#  term
# )
#  or
#  variable
#  (
# can
#  change
#  at
#  specified
#  times
# ).
#
# 3
# .
#  **
# Term
# **
# :
#  The
#  length
#  of
#  time
#  over
#  which
#  the
#  loan
#  must
#  be
#  rep
# aid
# ,
#  usually
#
# 15
# ,
#
# 20
# ,
#  or
#
# 30
#  years
# .
#
# 4
# .
#  **
# Monthly
#  Payments
# **
# :
#  Typically
#  consist
#  of
#  both
#  principal
#  and
#  interest
# ,
#  and
#  may
#  also
#  include
#  property
#  taxes
#  and
#  homeowners
#  insurance
#  (
# often
#  referred
#  to
#  as
#  P
# ITI
# :
#  Principal
# ,
#  Interest
# ,
#  Taxes
# ,
#  and
#  Insurance
# ).
#
# 5
# .
#  **
# Down
#  Payment
# **
# :
#  The
#  initial
#  amount
#  paid
#  upfront
#  when
#  purchasing
#  the
#  property
# ,
#  usually
#  expressed
#  as
#  a
#  percentage
#  of
#  the
#  purchase
#  price
# .
#  A
#  larger
#  down
#  payment
#  can
#  reduce
#  the
#  loan
#  amount
#  and
#  may
#  eliminate
#  the
#  need
#  for
#  private
#  mortgage
#  insurance
#  (
# PM
# I
# ).
#
# 6
# .
#  **
# Am
# ort
# ization
# **
# :
#  The
#  process
#  of
#  gradually
#  paying
#  off
#  the
#  loan
#  over
#  time
#  through
#  scheduled
#  payments
# .
#
#
# ###
#  Pros
#  of
#  Mort
# gages
#
#
#
# 1
# .
#  **
# Home
# ownership
# **
# :
#  Mort
# gages
#  enable
#  individuals
#  to
#  purchase
#  homes
#  without
#  needing
#  the
#  full
#  purchase
#  price
#  upfront
# ,
#  making
#  home
# ownership
#  accessible
#  to
#  more
#  people
# .
#
# 2
# .
#  **
# Equ
# ity
#  Building
# **
# :
#  As
#  you
#  make
#  mortgage
#  payments
# ,
#  you
#  build
#  equity
#  in
#  your
#  home
# ,
#  which
#  can
#  be
#  a
#  valuable
#  asset
#  over
#  time
# .
#
# 3
# .
#  **
# Tax
#  Benefits
# **
# :
#  In
#  many
#  countries
# ,
#  mortgage
#  interest
#  payments
#  may
#  be
#  tax
# -d
# educt
# ible
# ,
#  providing
#  potential
#  savings
#  for
#  homeowners
# .
#
# 4
# .
#  **
# Fixed
#  Payments
# **
# :
#  With
#  a
#  fixed
# -rate
#  mortgage
# ,
#  monthly
#  payments
#  remain
#  stable
# ,
#  making
#  budgeting
#  easier
# .
#
# 5
# .
#  **
# Le
# verage
# **
# :
#  Mort
# gages
#  allow
#  buyers
#  to
#  leverage
#  their
#  investment
# ,
#  meaning
#  they
#  can
#  control
#  a
#  larger
#  asset
#  with
#  a
#  smaller
#  initial
#  investment
#  (
# the
#  down
#  payment
# ).
#
# 6
# .
#  **
# Potential
#  Appreciation
# **
# :
#  Real
#  estate
#  often
#  appreciates
#  over
#  time
# ,
#  potentially
#  increasing
#  the
#  value
#  of
#  the
#  property
#  and
#  the
#  homeowner
# 's
#  equity
# .
#
#
# ###
#  Cons
#  of
#  Mort
# gages
#
#
#
# 1
# .
#  **
# Debt
#  Obl
# igation
# **
# :
#  A
#  mortgage
#  is
#  a
#  long
# -term
#  debt
#  that
#  requires
#  consistent
#  monthly
#  payments
# ,
#  which
#  can
#  be
#  a
#  financial
#  burden
#  if
#  income
#  fluctu
# ates
#  or
#  if
#  unexpected
#  expenses
#  arise
# .
#
# 2
# .
#  **
# Interest
#  Costs
# **
# :
#  Over
#  the
#  life
#  of
#  the
#  loan
# ,
#  borrowers
#  may
#  pay
#  a
#  significant
#  amount
#  in
#  interest
# ,
#  which
#  can
#  substantially
#  increase
#  the
#  total
#  cost
#  of
#  the
#  home
# .
#
# 3
# .
#  **
# Risk
#  of
#  Fore
# closure
# **
# :
#  If
#  a
#  borrower
#  fails
#  to
#  make
#  payments
# ,
#  the
#  lender
#  can
#  fore
# close
#  on
#  the
#  property
# ,
#  leading
#  to
#  the
#  loss
#  of
#  the
#  home
#  and
#  any
#  equity
#  built
# .
#
# 4
# .
#  **
# Market
#  Risk
# **
# :
#  Real
#  estate
#  values
#  can
#  fluctuate
# ,
#  and
#  if
#  the
#  market
#  declines
# ,
#  homeowners
#  may
#  find
#  themselves
#  owing
#  more
#  on
#  their
#  mortgage
#  than
#  their
#  home
#  is
#  worth
#  (
# under
# water
#  mortgage
# ).
#
# 5
# .
#  **
# Additional
#  Costs
# **
# :
#  Home
# ownership
#  comes
#  with
#  additional
#  costs
# ,
#  such
#  as
#  property
#  taxes
# ,
#  homeowners
#  insurance
# ,
#  maintenance
# ,
#  and
#  repairs
# ,
#  which
#  can
#  add
#  to
#  the
#  financial
#  burden
# .
#
# 6
# .
#  **
# Complex
# ity
# **
# :
#  The
#  mortgage
#  process
#  can
#  be
#  complicated
# ,
#  involving
#  various
#  fees
# ,
#  terms
# ,
#  and
#  conditions
#  that
#  borrowers
#  must
#  understand
# .
#
#
# ###
#  Conclusion
#
#
#
# A
#  mortgage
#  can
#  be
#  a
#  powerful
#  tool
#  for
#  achieving
#  home
# ownership
#  and
#  building
#  wealth
#  through
#  real
#  estate
# .
#  However
# ,
#  it
#  also
#  comes
#  with
#  risks
#  and
#  responsibilities
#  that
#  potential
#  borrowers
#  should
#  carefully
#  consider
# .
#  It's
#  essential
#  to
#  evaluate
#  personal
#  financial
#  situations
# ,
#  market
#  conditions
# ,
#  and
#  long
# -term
#  goals
#  before
#  committing
#  to
#  a
#  mortgage
# .
#  Consulting
#  with
#  financial
#  advisors
#  or
#  mortgage
#  professionals
#  can
#  also
#  provide
#  valuable
#  insights
#  tailored
#  to
#  individual
#  circumstances
# .

# %%
prompt = """Explain to me what is mortgage in detail with pros and cons"""
chat_template = ChatPromptTemplate.from_template(prompt)

response = []
for chunk in chatgpt.stream(chat_template.format()):
    print(chunk.content, end="")
    response.append(chunk.content)
# Out:
# A mortgage is a type of loan specifically used to purchase real estate, where the property itself serves as collateral for the loan. When a borrower takes out a mortgage, they agree to repay the loan amount, plus interest, over a specified period, typically 15 to 30 years. Mortgages are commonly used by individuals and families to buy homes, but they can also be used for investment properties or commercial real estate.
#
# ### Key Components of a Mortgage
#
# 1. **Principal**: The original loan amount borrowed from the lender.
# 2. **Interest Rate**: The cost of borrowing the principal, expressed as a percentage. This can be fixed (remains the same throughout the loan term) or variable (can change at specified times).
# 3. **Term**: The length of time over which the loan must be repaid, commonly 15, 20, or 30 years.
# 4. **Monthly Payments**: Typically consist of both principal and interest, and may also include property taxes and homeowners insurance (often referred to as PITI: Principal, Interest, Taxes, Insurance).
# 5. **Down Payment**: The initial amount paid upfront by the borrower, usually expressed as a percentage of the property’s purchase price. A larger down payment can reduce the loan amount and may eliminate the need for private mortgage insurance (PMI).
# 6. **Amortization**: The process of gradually paying off the loan through regular payments over the term of the mortgage.
#
# ### Types of Mortgages
#
# 1. **Fixed-Rate Mortgage**: The interest rate remains constant throughout the life of the loan.
# 2. **Adjustable-Rate Mortgage (ARM)**: The interest rate may change at specified intervals based on market conditions.
# 3. **Interest-Only Mortgage**: The borrower pays only the interest for a certain period, after which they begin paying both principal and interest.
# 4. **FHA Loans**: Insured by the Federal Housing Administration, these loans are designed for low-to-moderate-income borrowers and require lower down payments.
# 5. **VA Loans**: Available to veterans and active-duty military personnel, these loans often require no down payment and have favorable terms.
#
# ### Pros of Mortgages
#
# 1. **Homeownership**: Mortgages enable individuals to purchase homes without needing the full purchase price upfront.
# 2. **Building Equity**: As you make payments, you build equity in your home, which can be a valuable asset.
# 3. **Tax Benefits**: Mortgage interest and property taxes may be tax-deductible, providing potential savings.
# 4. **Fixed Payments**: With a fixed-rate mortgage, monthly payments remain stable, making budgeting easier.
# 5. **Leverage**: Mortgages allow you to leverage your investment, meaning you can control a larger asset with a smaller amount of your own money.
#
# ### Cons of Mortgages
#
# 1. **Debt Obligation**: A mortgage is a long-term debt that requires consistent payments, which can be a financial burden.
# 2. **Interest Costs**: Over the life of the loan, the total interest paid can be substantial, often exceeding the principal amount borrowed.
# 3. **Risk of Foreclosure**: If you fail to make payments, the lender can foreclose on the property, leading to loss of your home.
# 4. **Market Fluctuations**: Property values can decrease, potentially leaving you with a mortgage that exceeds the home’s value (underwater mortgage).
# 5. **Additional Costs**: Homeownership comes with other costs, such as maintenance, repairs, property taxes, and insurance, which can add to the financial burden.
#
# ### Conclusion
#
# A mortgage can be a powerful tool for achieving homeownership and building wealth over time. However, it is essential to understand the responsibilities and risks involved. Prospective borrowers should carefully consider their financial situation, the terms of the mortgage, and the long-term implications of taking on such a significant debt. Consulting with financial advisors or mortgage professionals can help individuals make informed decisions.

# %%
response[:10]
# Out:
# ['',
#  'A',
#  ' mortgage',
#  ' is',
#  ' a',
#  ' type',
#  ' of',
#  ' loan',
#  ' specifically',
#  ' used']

# %%
print(''.join(response))
# Out:
# A mortgage is a type of loan specifically used to purchase real estate, where the property itself serves as collateral for the loan. When a borrower takes out a mortgage, they agree to repay the loan amount, plus interest, over a specified period, typically 15 to 30 years. Mortgages are commonly used by individuals and families to buy homes, but they can also be used for investment properties or commercial real estate.
#
# ### Key Components of a Mortgage
#
# 1. **Principal**: The original loan amount borrowed from the lender.
# 2. **Interest Rate**: The cost of borrowing the principal, expressed as a percentage. This can be fixed (remains the same throughout the loan term) or variable (can change at specified times).
# 3. **Term**: The length of time over which the loan must be repaid, commonly 15, 20, or 30 years.
# 4. **Monthly Payments**: Typically consist of both principal and interest, and may also include property taxes and homeowners insurance (often referred to as PITI: Principal, Interest, Taxes, Insurance).
# 5. **Down Payment**: The initial amount paid upfront by the borrower, usually expressed as a percentage of the property’s purchase price. A larger down payment can reduce the loan amount and may eliminate the need for private mortgage insurance (PMI).
# 6. **Amortization**: The process of gradually paying off the loan through regular payments over the term of the mortgage.
#
# ### Types of Mortgages
#
# 1. **Fixed-Rate Mortgage**: The interest rate remains constant throughout the life of the loan.
# 2. **Adjustable-Rate Mortgage (ARM)**: The interest rate may change at specified intervals based on market conditions.
# 3. **Interest-Only Mortgage**: The borrower pays only the interest for a certain period, after which they begin paying both principal and interest.
# 4. **FHA Loans**: Insured by the Federal Housing Administration, these loans are designed for low-to-moderate-income borrowers and require lower down payments.
# 5. **VA Loans**: Available to veterans and active-duty military personnel, these loans often require no down payment and have favorable terms.
#
# ### Pros of Mortgages
#
# 1. **Homeownership**: Mortgages enable individuals to purchase homes without needing the full purchase price upfront.
# 2. **Building Equity**: As you make payments, you build equity in your home, which can be a valuable asset.
# 3. **Tax Benefits**: Mortgage interest and property taxes may be tax-deductible, providing potential savings.
# 4. **Fixed Payments**: With a fixed-rate mortgage, monthly payments remain stable, making budgeting easier.
# 5. **Leverage**: Mortgages allow you to leverage your investment, meaning you can control a larger asset with a smaller amount of your own money.
#
# ### Cons of Mortgages
#
# 1. **Debt Obligation**: A mortgage is a long-term debt that requires consistent payments, which can be a financial burden.
# 2. **Interest Costs**: Over the life of the loan, the total interest paid can be substantial, often exceeding the principal amount borrowed.
# 3. **Risk of Foreclosure**: If you fail to make payments, the lender can foreclose on the property, leading to loss of your home.
# 4. **Market Fluctuations**: Property values can decrease, potentially leaving you with a mortgage that exceeds the home’s value (underwater mortgage).
# 5. **Additional Costs**: Homeownership comes with other costs, such as maintenance, repairs, property taxes, and insurance, which can add to the financial burden.
#
# ### Conclusion
#
# A mortgage can be a powerful tool for achieving homeownership and building wealth over time. However, it is essential to understand the responsibilities and risks involved. Prospective borrowers should carefully consider their financial situation, the terms of the mortgage, and the long-term implications of taking on such a significant debt. Consulting with financial advisors or mortgage professionals can help individuals make informed decisions.
