# %% [markdown]
# Link: https://www.udemy.com/course/langchain-in-action-develop-llm-powered-applications/

# %% [markdown]
# # LLMs

# %%
from dotenv import load_dotenv, find_dotenv

load_dotenv(find_dotenv())
# Out:
# True

# %% [markdown]
# ### Text Completion models - DEPRECATED - we will just use ChatModels

# %%
from langchain_openai import OpenAI

llm = OpenAI()
llm("Tell me a joke")
# Out:
# /var/folders/b_/0hx_r16d2v712fg4k7y_rh140000gp/T/ipykernel_84351/2810639211.py:4: LangChainDeprecationWarning: The method `BaseLLM.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   llm("Tell me a joke")
# "\n\nWhy don't scientists trust atoms? Because they make up everything."

# %%
llm("Tell me a joke")
# Out:
# "\n\nWhy don't scientists trust atoms? \n\nBecause they make up everything."

# %%
llm.invoke(input="Tell me a joke")
# Out:
# "\n\nWhy couldn't the bicycle stand up by itself?\n\nBecause it was two-tired!"

# %% [markdown]
# Batch Processing - Make multiple requests at once

# %%
result = llm.generate(["Tell me a joke about cows", "Tell me a joke about parrots"])
print(result)
# Out:
# generations=[[Generation(text='\n\nWhy did the cow cross the road?\n\nTo get to the udder side!', generation_info={'finish_reason': 'stop', 'logprobs': None})], [Generation(text='\n\nWhy did the parrot wear a raincoat?\n\nBecause he heard it was going to be a little "polly"!', generation_info={'finish_reason': 'stop', 'logprobs': None})]] llm_output={'token_usage': {'prompt_tokens': 13, 'completion_tokens': 44, 'total_tokens': 57}, 'model_name': 'gpt-3.5-turbo-instruct'} run=[RunInfo(run_id=UUID('7b6df876-00cc-4ea1-98ce-76dcf636023a')), RunInfo(run_id=UUID('7ca950b0-b046-4ee7-9655-30e5b4e6158e'))] type='LLMResult'

# %%
result.llm_output
# Out:
# {'token_usage': {'prompt_tokens': 13,
#   'completion_tokens': 44,
#   'total_tokens': 57},
#  'model_name': 'gpt-3.5-turbo-instruct'}

# %% [markdown]
# ### Creating a conversation with SystemMessage, AIMessage and SystemMessage

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o-mini")

# %%
result = llm.invoke("Tell me a joke about cows")
print(result)
# Out:
# content='What do you call a cow that can play a musical instrument? \n\nA moo-sician! 🐄🎶' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 24, 'prompt_tokens': 13, 'total_tokens': 37, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_aa07c96156', 'id': 'chatcmpl-Clx18BEKJaDoxZWdnkxF9Xy6CHKpC', 'finish_reason': 'stop', 'logprobs': None} id='run-b4b35580-12aa-46f6-a0d0-1fca3f82a2ba-0' usage_metadata={'input_tokens': 13, 'output_tokens': 24, 'total_tokens': 37, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
from langchain.schema import SystemMessage, HumanMessage, AIMessage

messages = [
    SystemMessage(content="You are a helpful assistant specialized in providing information about BellaVista Italian Restaurant."),
    HumanMessage(content="What's on the menu?"),
    AIMessage(content="BellaVista offers a variety of Italian dishes including pasta, pizza, and seafood."),
    HumanMessage(content="Do you have vegan options?")
]

# %%
messages
# Out:
# [SystemMessage(content='You are a helpful assistant specialized in providing information about BellaVista Italian Restaurant.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content="What's on the menu?", additional_kwargs={}, response_metadata={}),
#  AIMessage(content='BellaVista offers a variety of Italian dishes including pasta, pizza, and seafood.', additional_kwargs={}, response_metadata={}),
#  HumanMessage(content='Do you have vegan options?', additional_kwargs={}, response_metadata={})]

# %%
llm_result = llm.invoke(input=messages)
llm_result
# Out:
# AIMessage(content="Yes, BellaVista Italian Restaurant typically includes vegan options on their menu. These may include dishes like vegan pasta, salads, and pizza with plant-based toppings. It's always a good idea to check with the restaurant for the most current vegan selections and any special modifications that can be made.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 57, 'prompt_tokens': 61, 'total_tokens': 118, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_b8bc95a0ac', 'id': 'chatcmpl-BEh15usEgC8xYPo3l25nTtHVvIKJJ', 'finish_reason': 'stop', 'logprobs': None}, id='run-52782c41-d3bb-497c-bf1e-57d8173bd12b-0', usage_metadata={'input_tokens': 61, 'output_tokens': 57, 'total_tokens': 118, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# Batch Processing for Chat Models - Make multiple requests at once

# %%
batch_messages = [
    [
        SystemMessage(content="You are a helpful assistant that translates English to German"),
        HumanMessage(content="Do you have vegan options?")
    ],
    [
        SystemMessage(content="You are a helpful assistant that translates the English to Spanish."),
        HumanMessage(content="Do you have vegan options?")
    ],
]
batch_result = llm.generate(batch_messages)
batch_result
# Out:
# LLMResult(generations=[[ChatGeneration(text='Haben Sie vegane Optionen?', generation_info={'finish_reason': 'stop', 'logprobs': None}, message=AIMessage(content='Haben Sie vegane Optionen?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 27, 'total_tokens': 34, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_11f3029f6b', 'id': 'chatcmpl-Clx1ggLvfuQ1wQXQ3aPDsHuNiiszS', 'finish_reason': 'stop', 'logprobs': None}, id='run-8cab4d8b-ce06-47d7-af95-4232b052981f-0', usage_metadata={'input_tokens': 27, 'output_tokens': 7, 'total_tokens': 34, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}))], [ChatGeneration(text='¿Tienen opciones veganas?', generation_info={'finish_reason': 'stop', 'logprobs': None}, message=AIMessage(content='¿Tienen opciones veganas?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 7, 'prompt_tokens': 29, 'total_tokens': 36, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_aa07c96156', 'id': 'chatcmpl-Clx1gYhSa0w6yf2AvlLfmqn9mq5Ee', 'finish_reason': 'stop', 'logprobs': None}, id='run-636afc81-4c19-4d65-803c-9f98a93f3e19-0', usage_metadata={'input_tokens': 29, 'output_tokens': 7, 'total_tokens': 36, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}))]], llm_output={'token_usage': {'completion_tokens': 14, 'prompt_tokens': 56, 'total_tokens': 70, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini', 'system_fingerprint': 'fp_11f3029f6b'}, run=[RunInfo(run_id=UUID('8cab4d8b-ce06-47d7-af95-4232b052981f')), RunInfo(run_id=UUID('636afc81-4c19-4d65-803c-9f98a93f3e19'))], type='LLMResult')

# %% [markdown]
# Extracting the output ourself (we will later take a look at Output-Parsers!)

# %%
batch_result.model_dump()
# Out:
# {'generations': [[{'text': 'Haben Sie vegane Optionen?',
#     'generation_info': {'finish_reason': 'stop', 'logprobs': None},
#     'type': 'ChatGeneration',
#     'message': {'content': 'Haben Sie vegane Optionen?',
#      'additional_kwargs': {'refusal': None},
#      'response_metadata': {'token_usage': {'completion_tokens': 7,
#        'prompt_tokens': 27,
#        'total_tokens': 34,
#        'completion_tokens_details': {'accepted_prediction_tokens': 0,
#         'audio_tokens': 0,
#         'reasoning_tokens': 0,
#         'rejected_prediction_tokens': 0},
#        'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}},
#       'model_name': 'gpt-4o-mini-2024-07-18',
#       'system_fingerprint': 'fp_11f3029f6b',
#       'id': 'chatcmpl-Clx1ggLvfuQ1wQXQ3aPDsHuNiiszS',
#       'finish_reason': 'stop',
#       'logprobs': None},
#      'type': 'ai',
#      'name': None,
#      'id': 'run-8cab4d8b-ce06-47d7-af95-4232b052981f-0'}}],
#   [{'text': '¿Tienen opciones veganas?',
#     'generation_info': {'finish_reason': 'stop', 'logprobs': None},
#     'type': 'ChatGeneration',
#     'message': {'content': '¿Tienen opciones veganas?',
#      'additional_kwargs': {'refusal': None},
#      'response_metadata': {'token_usage': {'completion_tokens': 7,
#        'prompt_tokens': 29,
#        'total_tokens': 36,
#        'completion_tokens_details': {'accepted_prediction_tokens': 0,
#         'audio_tokens': 0,
#         'reasoning_tokens': 0,
#         'rejected_prediction_tokens': 0},
#        'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}},
#       'model_name': 'gpt-4o-mini-2024-07-18',
#       'system_fingerprint': 'fp_aa07c96156',
#       'id': 'chatcmpl-Clx1gYhSa0w6yf2AvlLfmqn9mq5Ee',
#       'finish_reason': 'stop',
#       'logprobs': None},
#      'type': 'ai',
#      'name': None,
#      'id': 'run-636afc81-4c19-4d65-803c-9f98a93f3e19-0'}}]],
#  'llm_output': {'token_usage': {'completion_tokens': 14,
#    'prompt_tokens': 56,
#    'total_tokens': 70,
#    'completion_tokens_details': {'accepted_prediction_tokens': 0,
#     'audio_tokens': 0,
#     'reasoning_tokens': 0,
#     'rejected_prediction_tokens': 0},
#    'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}},
#   'model_name': 'gpt-4o-mini',
#   'system_fingerprint': 'fp_11f3029f6b'},
#  'run': [{'run_id': UUID('8cab4d8b-ce06-47d7-af95-4232b052981f')},
#   {'run_id': UUID('636afc81-4c19-4d65-803c-9f98a93f3e19')}],
#  'type': 'LLMResult'}

# %%
translations = [generation[0].text for generation in batch_result.generations]
translations
# Out:
# ['Haben Sie vegane Optionen?', '¿Tienen opciones veganas?']
